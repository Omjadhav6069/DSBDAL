# %%
import pandas as pd
import numpy as np

# %%
# !pip install -q kaggle

# %%
iris=pd.read_csv("/content/IRIS.csv");

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Mean
iris.mean()
# Out:
# <ipython-input-24-dd135d1f1581>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.mean()
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
iris.loc[:,'sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
species  = iris[iris["species"] == "Iris-setosa"]

# %%
species
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
species.mean()
# Out:
# <ipython-input-40-4cf36c004601>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.mean()
# sepal_length    5.006
# sepal_width     3.418
# petal_length    1.464
# petal_width     0.244
# dtype: float64

# %%
species.median()
# Out:
# <ipython-input-46-56d332feb636>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.median()
# sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# dtype: float64

# %%
species.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.0          3.4           1.5          0.2  Iris-setosa
# 1           5.1          NaN           NaN          NaN          NaN

# %%
species.std()
# Out:
# <ipython-input-48-18543f7cbfcd>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.std()
# sepal_length    0.352490
# sepal_width     0.381024
# petal_length    0.173511
# petal_width     0.107210
# dtype: float64

# %%
species.quantile(0.25)
# Out:
# <ipython-input-66-06409d6b0ac1>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.quantile(0.25)
# sepal_length    4.800
# sepal_width     3.125
# petal_length    1.400
# petal_width     0.200
# Name: 0.25, dtype: float64

# %%
species.quantile(0.50)
# Out:
# <ipython-input-67-a4dff42da3c4>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.quantile(0.50)
# sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# Name: 0.5, dtype: float64

# %%
species.quantile(0.75)
# Out:
# <ipython-input-68-0041d7eae106>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species.quantile(0.75)
# sepal_length    5.200
# sepal_width     3.675
# petal_length    1.575
# petal_width     0.300
# Name: 0.75, dtype: float64

# %%
species1  = iris[iris["species"] == "Iris-versicolor"]

# %%
species1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
# 57           4.9          2.4           3.3          1.0  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 59           5.2          2.7           3.9          1.4  Iris-versicolor
# 60           5.0          2.0           3.5          1.0  Iris-versicolor
# 61           5.9          3.0           4.2          1.5  Iris-versicolor
# ...

# %%
species1.mean()
# Out:
# <ipython-input-43-4e1db15aa885>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.mean()
# sepal_length    5.936
# sepal_width     2.770
# petal_length    4.260
# petal_width     1.326
# dtype: float64

# %%
species1.median()
# Out:
# <ipython-input-44-8d1f01535037>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.median()
# sepal_length    5.90
# sepal_width     2.80
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
species1.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.5          3.0           4.5          1.3  Iris-versicolor
# 1           5.6          NaN           NaN          NaN              NaN
# 2           5.7          NaN           NaN          NaN              NaN

# %%
species1.std()
# Out:
# <ipython-input-49-eb7f4711e54f>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.std()
# sepal_length    0.516171
# sepal_width     0.313798
# petal_length    0.469911
# petal_width     0.197753
# dtype: float64

# %%
species1.var()
# Out:
# <ipython-input-56-afcd319103af>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.var()
# sepal_length    0.266433
# sepal_width     0.098469
# petal_length    0.220816
# petal_width     0.039106
# dtype: float64

# %%
species1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
species1.max()
# Out:
# sepal_length                7.0
# sepal_width                 3.4
# petal_length                5.1
# petal_width                 1.8
# species         Iris-versicolor
# dtype: object

# %%
species1.quantile(.1)
# Out:
# <ipython-input-62-62b6ebddc14a>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.quantile(.1)
# sepal_length    5.38
# sepal_width     2.30
# petal_length    3.59
# petal_width     1.00
# Name: 0.1, dtype: float64

# %%
species1.quantile(.25)
# Out:
# <ipython-input-63-875c73352579>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.quantile(.25)
# sepal_length    5.600
# sepal_width     2.525
# petal_length    4.000
# petal_width     1.200
# Name: 0.25, dtype: float64

# %%
species1.quantile(.50)
# Out:
# <ipython-input-64-ffe0d91b0fd3>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.quantile(.50)
# sepal_length    5.90
# sepal_width     2.80
# petal_length    4.35
# petal_width     1.30
# Name: 0.5, dtype: float64

# %%
species1.quantile(.75)
# Out:
# <ipython-input-65-d2dacbd0ea22>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   species1.quantile(.75)
# sepal_length    6.3
# sepal_width     3.0
# petal_length    4.6
# petal_width     1.5
# Name: 0.75, dtype: float64
