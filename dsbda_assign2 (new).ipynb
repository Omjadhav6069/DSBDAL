# %% [markdown]
# Name: Om Jadhav
# Class :TE Comp(A)
# Roll No: 21CO050

# %% [markdown]
# Assignment No 2:Data Wrangling II
# Create an “Academic performance” dataset of students and perform the following operations using
# Python.
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable
# techniques to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this
# transformation should be one of the following reasons: to change the scale for better
# understanding of the variable, to convert a non-linear relation into a linear one, or to
# decrease the skewness and convert the distribution into a normal distribution.
# Reason and document your approach properly.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/DSBDA2(OM)1.csv");

# %%
df
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0         1    NaN   9.1   7.8  5.00  7.77  4.60
# 1         2    NaN   8.3   8.9  7.00  8.56  7.67
# 2         3    AJK   7.0   6.8  6.80  6.78  7.56
# 3         4     AB   6.0   8.6  9.00  7.80  7.86
# 4         5    SDD   8.4   5.8  8.90  8.90  8.76
# 5         6     DG   9.0   9.0  7.90  6.80  5.67
# 6         7    FGH   7.7   6.7  8.60  8.60  8.77
# 7         8    FGH   8.6   7.8  8.40  5.80  8.56
# 8         9     TU   7.8   8.6  6.80  9.00  6.78
# 9        10     HK   8.9   5.8  8.77  6.70  7.80
# 10       11    ER6   6.8   9.3  7.80  7.80  8.90
# 11       12     WE   8.6   8.6  8.90  8.60  6.80
# 12       13  SDGTS   5.8   9.5  7.50  5.80  8.60
# 13       14    NaN   9.0   9.9  8.60  9.30  5.80
# 14       15     ST   6.7   8.8  5.80  8.60  9.00
# 15       16    NaN   7.8   8.9  9.00  9.50  6.70
# 16       17    NaN   8.6   8.0  6.70  9.90  7.80
# 17       18     DG   5.8   7.9  7.80  8.80  8.60
# ...

# %%
df.head()
# Out:
#    roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0        1  NaN   9.1   7.8   5.0  7.77  4.60
# 1        2  NaN   8.3   8.9   7.0  8.56  7.67
# 2        3  AJK   7.0   6.8   6.8  6.78  7.56
# 3        4   AB   6.0   8.6   9.0  7.80  7.86
# 4        5  SDD   8.4   5.8   8.9  8.90  8.76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll no  30 non-null     int64
#  1   Name     20 non-null     object
#  2   SEM1     30 non-null     float64
#  3   SEM2     30 non-null     float64
#  4   SEM3     30 non-null     float64
#  5   SEM4     30 non-null     float64
#  6   SEM5     30 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df.describe(include="all")
# Out:
#           roll no Name       SEM1       SEM2       SEM3       SEM4       SEM5
# count   30.000000   20  30.000000  30.000000  30.000000  30.000000  30.000000
# unique        NaN   17        NaN        NaN        NaN        NaN        NaN
# top           NaN   WE        NaN        NaN        NaN        NaN        NaN
# freq          NaN    2        NaN        NaN        NaN        NaN        NaN
# mean    15.500000  NaN   8.176667   8.040000   8.035667   8.213667   8.035333
# std      8.803408  NaN   1.083953   1.147892   1.173041   1.071822   1.306653
# min      1.000000  NaN   5.800000   5.800000   5.000000   5.800000   4.600000
# 25%      8.250000  NaN   7.800000   7.125000   7.575000   7.800000   7.587500
# 50%     15.500000  NaN   8.600000   8.300000   8.500000   8.530000   8.600000
# 75%     22.750000  NaN   8.900000   8.900000   8.875000   8.900000   8.895000
# max     30.000000  NaN   9.900000   9.900000   9.900000   9.900000   9.900000

# %%
df.shape
# Out:
# (30, 7)

# %%
df.columns
# Out:
# Index(['roll no', 'Name', 'SEM1', 'SEM2', 'SEM3', 'SEM4', 'SEM5'], dtype='object')

# %%
df[0:5]
# Out:
#    roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0        1  NaN   9.1   7.8   5.0  7.77  4.60
# 1        2  NaN   8.3   8.9   7.0  8.56  7.67
# 2        3  AJK   7.0   6.8   6.8  6.78  7.56
# 3        4   AB   6.0   8.6   9.0  7.80  7.86
# 4        5  SDD   8.4   5.8   8.9  8.90  8.76

# %%
df.loc[0:2]
# Out:
#    roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0        1  NaN   9.1   7.8   5.0  7.77  4.60
# 1        2  NaN   8.3   8.9   7.0  8.56  7.67
# 2        3  AJK   7.0   6.8   6.8  6.78  7.56

# %%
df.loc[0:2,'SEM1':'SEM5']
# Out:
#    SEM1  SEM2  SEM3  SEM4  SEM5
# 0   9.1   7.8   5.0  7.77  4.60
# 1   8.3   8.9   7.0  8.56  7.67
# 2   7.0   6.8   6.8  6.78  7.56

# %%
df.iloc[1:5,1:5]
# Out:
#   Name  SEM1  SEM2  SEM3
# 1  NaN   8.3   8.9   7.0
# 2  AJK   7.0   6.8   6.8
# 3   AB   6.0   8.6   9.0
# 4  SDD   8.4   5.8   8.9

# %%
 df.isnull()
# Out:
#     roll no   Name   SEM1   SEM2   SEM3   SEM4   SEM5
# 0     False   True  False  False  False  False  False
# 1     False   True  False  False  False  False  False
# 2     False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False
# 7     False  False  False  False  False  False  False
# 8     False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False
# 11    False  False  False  False  False  False  False
# 12    False  False  False  False  False  False  False
# 13    False   True  False  False  False  False  False
# 14    False  False  False  False  False  False  False
# 15    False   True  False  False  False  False  False
# ...

# %%
df.isna()
# Out:
#     roll no   Name   SEM1   SEM2   SEM3   SEM4   SEM5
# 0     False   True  False  False  False  False  False
# 1     False   True  False  False  False  False  False
# 2     False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False
# 7     False  False  False  False  False  False  False
# 8     False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False
# 11    False  False  False  False  False  False  False
# 12    False  False  False  False  False  False  False
# 13    False   True  False  False  False  False  False
# 14    False  False  False  False  False  False  False
# 15    False   True  False  False  False  False  False
# ...

# %%
df.isnull().any()
# Out:
# roll no    False
# Name        True
# SEM1       False
# SEM2       False
# SEM3       False
# SEM4       False
# SEM5       False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# roll no     0
# Name       10
# SEM1        0
# SEM2        0
# SEM3        0
# SEM4        0
# SEM5        0
# dtype: int64

# %%
df.Name.isnull().sum()
# Out:
# 10

# %%
cols_with_na=[]
for col in df.columns:
  if df[col].isna().any():
    cols_with_na.append(col)

cols_with_na
# Out:
# ['Name']

# %%
df.replace(np.nan,value=0)
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0         1      0   9.1   7.8  5.00  7.77  4.60
# 1         2      0   8.3   8.9  7.00  8.56  7.67
# 2         3    AJK   7.0   6.8  6.80  6.78  7.56
# 3         4     AB   6.0   8.6  9.00  7.80  7.86
# 4         5    SDD   8.4   5.8  8.90  8.90  8.76
# 5         6     DG   9.0   9.0  7.90  6.80  5.67
# 6         7    FGH   7.7   6.7  8.60  8.60  8.77
# 7         8    FGH   8.6   7.8  8.40  5.80  8.56
# 8         9     TU   7.8   8.6  6.80  9.00  6.78
# 9        10     HK   8.9   5.8  8.77  6.70  7.80
# 10       11    ER6   6.8   9.3  7.80  7.80  8.90
# 11       12     WE   8.6   8.6  8.90  8.60  6.80
# 12       13  SDGTS   5.8   9.5  7.50  5.80  8.60
# 13       14      0   9.0   9.9  8.60  9.30  5.80
# 14       15     ST   6.7   8.8  5.80  8.60  9.00
# 15       16      0   7.8   8.9  9.00  9.50  6.70
# 16       17      0   8.6   8.0  6.70  9.90  7.80
# 17       18     DG   5.8   7.9  7.80  8.80  8.60
# ...

# %%
df.fillna(1)
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0         1      1   9.1   7.8  5.00  7.77  4.60
# 1         2      1   8.3   8.9  7.00  8.56  7.67
# 2         3    AJK   7.0   6.8  6.80  6.78  7.56
# 3         4     AB   6.0   8.6  9.00  7.80  7.86
# 4         5    SDD   8.4   5.8  8.90  8.90  8.76
# 5         6     DG   9.0   9.0  7.90  6.80  5.67
# 6         7    FGH   7.7   6.7  8.60  8.60  8.77
# 7         8    FGH   8.6   7.8  8.40  5.80  8.56
# 8         9     TU   7.8   8.6  6.80  9.00  6.78
# 9        10     HK   8.9   5.8  8.77  6.70  7.80
# 10       11    ER6   6.8   9.3  7.80  7.80  8.90
# 11       12     WE   8.6   8.6  8.90  8.60  6.80
# 12       13  SDGTS   5.8   9.5  7.50  5.80  8.60
# 13       14      1   9.0   9.9  8.60  9.30  5.80
# 14       15     ST   6.7   8.8  5.80  8.60  9.00
# 15       16      1   7.8   8.9  9.00  9.50  6.70
# 16       17      1   8.6   8.0  6.70  9.90  7.80
# 17       18     DG   5.8   7.9  7.80  8.80  8.60
# ...

# %%
df['SEM2']=df['SEM3'].fillna(df['SEM2'].mean())

# %%
df.head(10)
# Out:
#    roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0        1  NaN   9.1  5.00  5.00  7.77  4.60
# 1        2  NaN   8.3  7.00  7.00  8.56  7.67
# 2        3  AJK   7.0  6.80  6.80  6.78  7.56
# 3        4   AB   6.0  9.00  9.00  7.80  7.86
# 4        5  SDD   8.4  8.90  8.90  8.90  8.76
# 5        6   DG   9.0  7.90  7.90  6.80  5.67
# 6        7  FGH   7.7  8.60  8.60  8.60  8.77
# 7        8  FGH   8.6  8.40  8.40  5.80  8.56
# 8        9   TU   7.8  6.80  6.80  9.00  6.78
# 9       10   HK   8.9  8.77  8.77  6.70  7.80

# %%
df.dropna()
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 2         3    AJK   7.0  6.80  6.80  6.78  7.56
# 3         4     AB   6.0  9.00  9.00  7.80  7.86
# 4         5    SDD   8.4  8.90  8.90  8.90  8.76
# 5         6     DG   9.0  7.90  7.90  6.80  5.67
# 6         7    FGH   7.7  8.60  8.60  8.60  8.77
# 7         8    FGH   8.6  8.40  8.40  5.80  8.56
# 8         9     TU   7.8  6.80  6.80  9.00  6.78
# 9        10     HK   8.9  8.77  8.77  6.70  7.80
# 10       11    ER6   6.8  7.80  7.80  7.80  8.90
# 11       12     WE   8.6  8.90  8.90  8.60  6.80
# 12       13  SDGTS   5.8  7.50  7.50  5.80  8.60
# 14       15     ST   6.7  5.80  5.80  8.60  9.00
# 17       18     DG   5.8  7.80  7.80  8.80  8.60
# 18       19     RY   9.3  8.60  8.60  8.90  5.80
# 19       20    GHJ   8.6  5.80  5.80  8.00  9.30
# 21       22    CGH   9.9  8.60  8.60  7.80  9.50
# 23       24    CVN   8.9  9.90  9.90  8.00  9.50
# 25       26     WE   7.9  8.90  8.90  7.80  8.80
# ...

# %%
df.dropna(how="all")
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 0         1    NaN   9.1  5.00  5.00  7.77  4.60
# 1         2    NaN   8.3  7.00  7.00  8.56  7.67
# 2         3    AJK   7.0  6.80  6.80  6.78  7.56
# 3         4     AB   6.0  9.00  9.00  7.80  7.86
# 4         5    SDD   8.4  8.90  8.90  8.90  8.76
# 5         6     DG   9.0  7.90  7.90  6.80  5.67
# 6         7    FGH   7.7  8.60  8.60  8.60  8.77
# 7         8    FGH   8.6  8.40  8.40  5.80  8.56
# 8         9     TU   7.8  6.80  6.80  9.00  6.78
# 9        10     HK   8.9  8.77  8.77  6.70  7.80
# 10       11    ER6   6.8  7.80  7.80  7.80  8.90
# 11       12     WE   8.6  8.90  8.90  8.60  6.80
# 12       13  SDGTS   5.8  7.50  7.50  5.80  8.60
# 13       14    NaN   9.0  8.60  8.60  9.30  5.80
# 14       15     ST   6.7  5.80  5.80  8.60  9.00
# 15       16    NaN   7.8  9.00  9.00  9.50  6.70
# 16       17    NaN   8.6  6.70  6.70  9.90  7.80
# 17       18     DG   5.8  7.80  7.80  8.80  8.60
# ...

# %%
df.dropna(axis=1)
# Out:
#     roll no  SEM1  SEM2  SEM3  SEM4  SEM5
# 0         1   9.1  5.00  5.00  7.77  4.60
# 1         2   8.3  7.00  7.00  8.56  7.67
# 2         3   7.0  6.80  6.80  6.78  7.56
# 3         4   6.0  9.00  9.00  7.80  7.86
# 4         5   8.4  8.90  8.90  8.90  8.76
# 5         6   9.0  7.90  7.90  6.80  5.67
# 6         7   7.7  8.60  8.60  8.60  8.77
# 7         8   8.6  8.40  8.40  5.80  8.56
# 8         9   7.8  6.80  6.80  9.00  6.78
# 9        10   8.9  8.77  8.77  6.70  7.80
# 10       11   6.8  7.80  7.80  7.80  8.90
# 11       12   8.6  8.90  8.90  8.60  6.80
# 12       13   5.8  7.50  7.50  5.80  8.60
# 13       14   9.0  8.60  8.60  9.30  5.80
# 14       15   6.7  5.80  5.80  8.60  9.00
# 15       16   7.8  9.00  9.00  9.50  6.70
# 16       17   8.6  6.70  6.70  9.90  7.80
# 17       18   5.8  7.80  7.80  8.80  8.60
# 18       19   9.3  8.60  8.60  8.90  5.80
# 19       20   8.6  5.80  5.80  8.00  9.30
# 20       21   9.5  9.30  9.30  7.90  8.60
# ...

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df
# Out:
#     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 2         3    AJK   7.0  6.80  6.80  6.78  7.56
# 3         4     AB   6.0  9.00  9.00  7.80  7.86
# 4         5    SDD   8.4  8.90  8.90  8.90  8.76
# 5         6     DG   9.0  7.90  7.90  6.80  5.67
# 6         7    FGH   7.7  8.60  8.60  8.60  8.77
# 7         8    FGH   8.6  8.40  8.40  5.80  8.56
# 8         9     TU   7.8  6.80  6.80  9.00  6.78
# 9        10     HK   8.9  8.77  8.77  6.70  7.80
# 10       11    ER6   6.8  7.80  7.80  7.80  8.90
# 11       12     WE   8.6  8.90  8.90  8.60  6.80
# 12       13  SDGTS   5.8  7.50  7.50  5.80  8.60
# 14       15     ST   6.7  5.80  5.80  8.60  9.00
# 17       18     DG   5.8  7.80  7.80  8.80  8.60
# 18       19     RY   9.3  8.60  8.60  8.90  5.80
# 19       20    GHJ   8.6  5.80  5.80  8.00  9.30
# 21       22    CGH   9.9  8.60  8.60  7.80  9.50
# 23       24    CVN   8.9  9.90  9.90  8.00  9.50
# 25       26     WE   7.9  8.90  8.90  7.80  8.80
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.boxplot
# Out:
# <bound method boxplot_frame of     roll no   Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 2         3    AJK   7.0  6.80  6.80  6.78  7.56
# 3         4     AB   6.0  9.00  9.00  7.80  7.86
# 4         5    SDD   8.4  8.90  8.90  8.90  8.76
# 5         6     DG   9.0  7.90  7.90  6.80  5.67
# 6         7    FGH   7.7  8.60  8.60  8.60  8.77
# 7         8    FGH   8.6  8.40  8.40  5.80  8.56
# 8         9     TU   7.8  6.80  6.80  9.00  6.78
# 9        10     HK   8.9  8.77  8.77  6.70  7.80
# 10       11    ER6   6.8  7.80  7.80  7.80  8.90
# 11       12     WE   8.6  8.90  8.90  8.60  6.80
# 12       13  SDGTS   5.8  7.50  7.50  5.80  8.60
# 14       15     ST   6.7  5.80  5.80  8.60  9.00
# 17       18     DG   5.8  7.80  7.80  8.80  8.60
# 18       19     RY   9.3  8.60  8.60  8.90  5.80
# 19       20    GHJ   8.6  5.80  5.80  8.00  9.30
# 21       22    CGH   9.9  8.60  8.60  7.80  9.50
# 23       24    CVN   8.9  9.90  9.90  8.00  9.50
# 25       26     WE   7.9  8.90  8.90  7.80  8.80
# ...

# %%
sns.boxplot(x=df.Name)
# Out:
# <Axes: xlabel='Name'>

# %%
sns.boxplot(x=df.SEM1)
# Out:
# <Axes: xlabel='SEM1'>

# %%
sns.boxplot(x=df.SEM5)
# Out:
# <Axes: xlabel='SEM5'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['roll no','SEM11','SEM2','SEM3']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)
count=0
for r in range(2):
    for c in range(2):
         _= df[df_list[count]].plot(kind = 'box', ax=axes[r,c])
count+=1

# %%
Q1 = df['SEM5'].quantile(0.25)
Q3 = df['SEM5'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Q1 = 7.74, Q3 = 8.9, IQR = 1.1600000000000001, Lower_limit = 6.0, Upper_limit = 10.64

# %%
df[(df['SEM5'] < Lower_limit) | (df['SEM5'] > Upper_limit)]
# Out:
#     roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 5         6   DG   9.0   7.9   7.9   6.8  5.67
# 18       19   RY   9.3   8.6   8.6   8.9  5.80

# %%
outliers=[]
for i in df.SEM5:
    if i<Lower_limit or i>Upper_limit:
          outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are [5.67, 5.8]

# %%
Upper_limit
# Out:
# 10.64

# %%
Lower_limit
# Out:
# 6.0

# %%
df[df.SEM5<Lower_limit].index
# Out:
# Int64Index([5, 18], dtype='int64')

# %%
df1=df.drop(df[df.SEM5<Lower_limit].index)

# %%
df1.shape
# Out:
# (18, 7)

# %%
df2=df[df.SEM5<Lower_limit]
df2
# Out:
#     roll no Name  SEM1  SEM2  SEM3  SEM4  SEM5
# 5         6   DG   9.0   7.9   7.9   6.8  5.67
# 18       19   RY   9.3   8.6   8.6   8.9  5.80

# %%
sns.kdeplot(df.SEM5)
# Out:
# <Axes: xlabel='SEM5', ylabel='Density'>

# %%
sns.kdeplot(df.SEM5)
# Out:
# <Axes: xlabel='SEM5', ylabel='Density'>

# %%
df.SEM5
# Out:
# 2     7.56
# 3     7.86
# 4     8.76
# 5     5.67
# 6     8.77
# 7     8.56
# 8     6.78
# 9     7.80
# 10    8.90
# 11    6.80
# 12    8.60
# 14    9.00
# 17    8.60
# 18    5.80
# 19    9.30
# 21    9.50
# 23    9.50
# 25    8.80
# 26    8.90
# 28    8.88
# Name: SEM5, dtype: float64

# %%
log_SEM5=np.log(df.SEM5)
log_SEM5
# Out:
# 2     2.022871
# 3     2.061787
# 4     2.170196
# 5     1.735189
# 6     2.171337
# 7     2.147100
# 8     1.913977
# 9     2.054124
# 10    2.186051
# 11    1.916923
# 12    2.151762
# 14    2.197225
# 17    2.151762
# 18    1.757858
# 19    2.230014
# 21    2.251292
# 23    2.251292
# 25    2.174752
# 26    2.186051
# 28    2.183802
# Name: SEM5, dtype: float64

# %%
sns.kdeplot(log_SEM5)
# Out:
# <Axes: xlabel='SEM5', ylabel='Density'>

# %% [markdown]
# **DATA TRANSFORMATION **

# %%
import seaborn as sns

# %%
df.skew()
# Out:
# <ipython-input-59-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# roll no    0.350116
# SEM1      -0.496339
# SEM2      -0.740156
# SEM3      -0.740156
# SEM4      -0.909086
# SEM5      -1.138530
# dtype: float64

# %%
sns.kdeplot(df.SEM1)
# Out:
# <Axes: xlabel='SEM1', ylabel='Density'>

# %%
sns.kdeplot(df.SEM2)
# Out:
# <Axes: xlabel='SEM2', ylabel='Density'>

# %%
sns.kdeplot(df.SEM3)
# Out:
# <Axes: xlabel='SEM3', ylabel='Density'>

# %%
sns.kdeplot(df.SEM4)
# Out:
# <Axes: xlabel='SEM4', ylabel='Density'>

# %%
sns.kdeplot(df.SEM5)
# Out:
# <Axes: xlabel='SEM5', ylabel='Density'>
